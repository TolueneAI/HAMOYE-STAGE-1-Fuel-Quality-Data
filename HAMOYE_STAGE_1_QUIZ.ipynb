# %% [markdown]
# <a href="https://colab.research.google.com/github/TolueneAI/HAMOYE-STAGE-1-Fuel-Quality-Data/blob/master/HAMOYE_STAGE_1_QUIZ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
A = [1,2,3,4,5,6]

# %%
 B = [13, 21, 34]

# %%
A
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
B
# Out:
# [13, 21, 34]

# %%
A_B = A.extend[12]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-b72745253c9c> in <module>()
# ----> 1 A_B = A.extend[12]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
fuel_data = pd.read_csv(r'https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv')

# %%
fuel_data
# Out:
#                      record_id  ...  fuel_cost_per_mmbtu
# 0        f1_fuel_1994_12_1_0_7  ...                1.121
# 1       f1_fuel_1994_12_1_0_10  ...                1.120
# 2        f1_fuel_1994_12_2_0_1  ...                1.650
# 3        f1_fuel_1994_12_2_0_7  ...                1.970
# 4       f1_fuel_1994_12_2_0_10  ...                2.570
# ...                        ...  ...                  ...
# 29518  f1_fuel_2018_12_12_0_13  ...                9.030
# 29519   f1_fuel_2018_12_12_1_1  ...                6.950
# 29520  f1_fuel_2018_12_12_1_10  ...                8.990
# 29521  f1_fuel_2018_12_12_1_13  ...                1.110
# 29522  f1_fuel_2018_12_12_1_14  ...               11.680
#
# [29523 rows x 11 columns]

# %%
fuel_data['fuel_cost_per_unit_burned'].mean()
# Out:
# 208.64903102665716

# %%
fuel_data['fuel_type_code_pudl'].describe()
# Out:
# count     29523
# unique        6
# top         gas
# freq      11486
# Name: fuel_type_code_pudl, dtype: object

# %%
fuel_data['fuel_mmbtu_per_unit'].describe()
# Out:
# count    29523.000000
# mean         8.492111
# std         10.600220
# min          0.000001
# 25%          1.024000
# 50%          5.762694
# 75%         17.006000
# max        341.260000
# Name: fuel_mmbtu_per_unit, dtype: float64

# %%
fuel_data['fuel_qty_burned'].skew()
# Out:
# 15.851495469109503

# %%
fuel_data['fuel_qty_burned'].kurt()
# Out:
# 651.3694501337732

# %%
 fuel_data.isna().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
fuel_data.dropna().count()
# Out:
# record_id                       29343
# utility_id_ferc1                29343
# report_year                     29343
# plant_name_ferc1                29343
# fuel_type_code_pudl             29343
# fuel_unit                       29343
# fuel_qty_burned                 29343
# fuel_mmbtu_per_unit             29343
# fuel_cost_per_unit_burned       29343
# fuel_cost_per_unit_delivered    29343
# fuel_cost_per_mmbtu             29343
# dtype: int64

# %%
fuel_data.shape
# Out:
# (29523, 11)

# %%
percentage_missing = (29343/29523)*100

# %%
percentage_missing
# Out:
# 99.39030586322528

# %%
fuel_data['fuel_unit'].describe()
# Out:
# count     29343
# unique        9
# top         mcf
# freq      11354
# Name: fuel_unit, dtype: object

# %%
fuel_data.corr()
# Out:
#                               utility_id_ferc1  ...  fuel_cost_per_mmbtu
# utility_id_ferc1                      1.000000  ...             0.006122
# report_year                           0.093323  ...             0.010261
# fuel_qty_burned                      -0.057447  ...            -0.001896
# fuel_mmbtu_per_unit                  -0.066946  ...            -0.005884
# fuel_cost_per_unit_burned            -0.037863  ...            -0.000437
# fuel_cost_per_unit_delivered         -0.016414  ...            -0.000109
# fuel_cost_per_mmbtu                   0.006122  ...             1.000000
#
# [7 rows x 7 columns]

# %%
fuel_data['fuel_cost_per_unit_burned'].head(50)
# Out:
# 0        18.590
# 1        18.580
# 2        39.720
# 3        47.210
# 4         2.770
# 5        44.240
# 6        28.770
# 7        58.540
# 8        33.970
# 9        28.730
# 10        1.940
# 11       28.710
# 12        1.940
# 13       30.248
# 14       32.130
# 15       44.404
# 16       44.312
# 17       36.268
# 18       46.024
# 19       33.321
# 20       39.911
# 21       30.319
# 22       39.850
# 23       32.184
# 24       40.144
# 25       32.186
# 26       31.520
# 27       32.650
# 28        2.490
# 29       21.170
# 30        2.690
# 31       21.990
# 32        2.980
# 33        2.180
# 34       33.700
# 35        2.210
# 36       39.140
# 37        2.380
# 38       24.020
# 39        2.300
# 40       39.880
# 41        2.540
# 42        2.210
# 43       53.710
# 44        1.930
# 45    40803.000
# 46       30.410
# 47        2.290
# 48       44.920
# 49       34.180
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
fuel_data.head(50)
# Out:
#                  record_id  ...  fuel_cost_per_mmbtu
# 0    f1_fuel_1994_12_1_0_7  ...                1.121
# 1   f1_fuel_1994_12_1_0_10  ...                1.120
# 2    f1_fuel_1994_12_2_0_1  ...                1.650
# 3    f1_fuel_1994_12_2_0_7  ...                1.970
# 4   f1_fuel_1994_12_2_0_10  ...                2.570
# 5   f1_fuel_1994_12_2_0_13  ...                1.850
# 6    f1_fuel_1994_12_2_1_1  ...                0.450
# 7   f1_fuel_1994_12_2_1_10  ...                2.360
# 8   f1_fuel_1994_12_2_2_10  ...                1.400
# 9    f1_fuel_1994_12_4_0_1  ...                1.278
# 10   f1_fuel_1994_12_4_0_2  ...               13.900
# 11   f1_fuel_1994_12_4_0_4  ...                1.280
# 12   f1_fuel_1994_12_4_0_5  ...                1.900
# 13   f1_fuel_1994_12_6_0_1  ...                1.208
# 14   f1_fuel_1994_12_6_0_2  ...                5.469
# 15   f1_fuel_1994_12_6_0_4  ...                1.812
# 16   f1_fuel_1994_12_6_0_7  ...                1.806
# ...

# %%
fuel_data['fuel_type_code_pudl'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        coal
# 1        coal
# 2        coal
# 3        coal
# 4         gas
#          ...
# 29518     gas
# 29519     gas
# 29520     gas
# 29521    coal
# 29522     gas
# Name: fuel_type_code_pudl, Length: 29523, dtype: object>

# %%
fuel_data.iloc[5000:5050]
# Out:
#                      record_id  ...  fuel_cost_per_mmbtu
# 5000   f1_fuel_1998_12_133_0_6  ...              5.12000
# 5001   f1_fuel_1998_12_133_0_8  ...              2.51000
# 5002   f1_fuel_1998_12_133_1_5  ...              2.71000
# 5003   f1_fuel_1998_12_133_2_2  ...              2.58000
# 5004  f1_fuel_1998_12_133_2_14  ...              2.58000
# 5005   f1_fuel_1998_12_133_3_2  ...              2.58000
# 5006   f1_fuel_1998_12_136_0_1  ...              0.52900
# 5007   f1_fuel_1998_12_136_0_4  ...              1.36700
# 5008   f1_fuel_1998_12_136_0_7  ...              1.53600
# 5009  f1_fuel_1998_12_136_0_10  ...              1.16800
# 5010   f1_fuel_1998_12_136_1_1  ...              1.23000
# 5011   f1_fuel_1998_12_136_1_4  ...              1.37300
# 5012   f1_fuel_1998_12_136_2_1  ...              2.19700
# 5013   f1_fuel_1998_12_136_2_5  ...              2.66600
# 5014   f1_fuel_1998_12_137_0_1  ...              1.21500
# ...

# %%
fuel_data['report_year'].describe()
# Out:
# count    29523.000000
# mean      2005.806050
# std          7.025483
# min       1994.000000
# 25%       2000.000000
# 50%       2006.000000
# 75%       2012.000000
# max       2018.000000
# Name: report_year, dtype: float64

# %%
fuel_data['fuel_cost_per_unit_delivered'].mean()
# Out:
# 917.5704491074691

# %%
fuel_data.tail(60)
# Out:
#                       record_id  ...  fuel_cost_per_mmbtu
# 29463  f1_fuel_2018_12_150_1_14  ...             16.52100
# 29464   f1_fuel_2018_12_150_2_1  ...              3.89200
# 29465   f1_fuel_2018_12_150_2_2  ...             20.32400
# 29466   f1_fuel_2018_12_150_2_4  ...             11.64400
# 29467   f1_fuel_2018_12_150_2_5  ...             20.32400
# 29468   f1_fuel_2018_12_193_0_1  ...              3.41796
# 29469   f1_fuel_2018_12_193_0_4  ...              2.09295
# 29470   f1_fuel_2018_12_193_0_6  ...              8.30998
# 29471   f1_fuel_2018_12_193_0_7  ...              3.10279
# 29472  f1_fuel_2018_12_193_0_10  ...              3.35184
# 29473  f1_fuel_2018_12_193_0_13  ...              1.63672
# 29474  f1_fuel_2018_12_193_0_15  ...              4.19660
# 29475   f1_fuel_2018_12_193_1_1  ...              2.36112
# 29476   f1_fuel_2018_12_193_1_5  ...              3.18960
# 29477   f1_fuel_2018_12_193_1_7  ...            273.82100
# ...

# %%
fuel_data['report_year'].describe()
# Out:
# count    29523.000000
# mean      2005.806050
# std          7.025483
# min       1994.000000
# 25%       2000.000000
# 50%       2006.000000
# 75%       2012.000000
# max       2018.000000
# Name: report_year, dtype: float64
