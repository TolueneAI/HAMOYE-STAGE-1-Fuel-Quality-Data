# %% [markdown]
# <a href="https://colab.research.google.com/github/TolueneAI/HAMOYE-STAGE-1-Fuel-Quality-Data/blob/master/HAMOYE_STAGE_1_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fuel_data = pd.read_csv(r'https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv')

# %%
fuel_data
# Out:
#                      record_id  ...  fuel_cost_per_mmbtu
# 0        f1_fuel_1994_12_1_0_7  ...                1.121
# 1       f1_fuel_1994_12_1_0_10  ...                1.120
# 2        f1_fuel_1994_12_2_0_1  ...                1.650
# 3        f1_fuel_1994_12_2_0_7  ...                1.970
# 4       f1_fuel_1994_12_2_0_10  ...                2.570
# ...                        ...  ...                  ...
# 29518  f1_fuel_2018_12_12_0_13  ...                9.030
# 29519   f1_fuel_2018_12_12_1_1  ...                6.950
# 29520  f1_fuel_2018_12_12_1_10  ...                8.990
# 29521  f1_fuel_2018_12_12_1_13  ...                1.110
# 29522  f1_fuel_2018_12_12_1_14  ...               11.680
#
# [29523 rows x 11 columns]

# %%
fuel_data.index
# Out:
# RangeIndex(start=0, stop=29523, step=1)

# %%
fuel_data.columns
# Out:
# Index(['record_id', 'utility_id_ferc1', 'report_year', 'plant_name_ferc1',
#        'fuel_type_code_pudl', 'fuel_unit', 'fuel_qty_burned',
#        'fuel_mmbtu_per_unit', 'fuel_cost_per_unit_burned',
#        'fuel_cost_per_unit_delivered', 'fuel_cost_per_mmbtu'],
#       dtype='object')

# %%
fuel_data.shape
# Out:
# (29523, 11)

# %%
fuel_data.head()
# Out:
#                 record_id  ...  fuel_cost_per_mmbtu
# 0   f1_fuel_1994_12_1_0_7  ...                1.121
# 1  f1_fuel_1994_12_1_0_10  ...                1.120
# 2   f1_fuel_1994_12_2_0_1  ...                1.650
# 3   f1_fuel_1994_12_2_0_7  ...                1.970
# 4  f1_fuel_1994_12_2_0_10  ...                2.570
#
# [5 rows x 11 columns]

# %%
fuel_data.head(20)
# Out:
#                  record_id  ...  fuel_cost_per_mmbtu
# 0    f1_fuel_1994_12_1_0_7  ...                1.121
# 1   f1_fuel_1994_12_1_0_10  ...                1.120
# 2    f1_fuel_1994_12_2_0_1  ...                1.650
# 3    f1_fuel_1994_12_2_0_7  ...                1.970
# 4   f1_fuel_1994_12_2_0_10  ...                2.570
# 5   f1_fuel_1994_12_2_0_13  ...                1.850
# 6    f1_fuel_1994_12_2_1_1  ...                0.450
# 7   f1_fuel_1994_12_2_1_10  ...                2.360
# 8   f1_fuel_1994_12_2_2_10  ...                1.400
# 9    f1_fuel_1994_12_4_0_1  ...                1.278
# 10   f1_fuel_1994_12_4_0_2  ...               13.900
# 11   f1_fuel_1994_12_4_0_4  ...                1.280
# 12   f1_fuel_1994_12_4_0_5  ...                1.900
# 13   f1_fuel_1994_12_6_0_1  ...                1.208
# 14   f1_fuel_1994_12_6_0_2  ...                5.469
# 15   f1_fuel_1994_12_6_0_4  ...                1.812
# 16   f1_fuel_1994_12_6_0_7  ...                1.806
# ...

# %%
fuel_data.head(60)
# Out:
#                  record_id  ...  fuel_cost_per_mmbtu
# 0    f1_fuel_1994_12_1_0_7  ...                1.121
# 1   f1_fuel_1994_12_1_0_10  ...                1.120
# 2    f1_fuel_1994_12_2_0_1  ...                1.650
# 3    f1_fuel_1994_12_2_0_7  ...                1.970
# 4   f1_fuel_1994_12_2_0_10  ...                2.570
# 5   f1_fuel_1994_12_2_0_13  ...                1.850
# 6    f1_fuel_1994_12_2_1_1  ...                0.450
# 7   f1_fuel_1994_12_2_1_10  ...                2.360
# 8   f1_fuel_1994_12_2_2_10  ...                1.400
# 9    f1_fuel_1994_12_4_0_1  ...                1.278
# 10   f1_fuel_1994_12_4_0_2  ...               13.900
# 11   f1_fuel_1994_12_4_0_4  ...                1.280
# 12   f1_fuel_1994_12_4_0_5  ...                1.900
# 13   f1_fuel_1994_12_6_0_1  ...                1.208
# 14   f1_fuel_1994_12_6_0_2  ...                5.469
# 15   f1_fuel_1994_12_6_0_4  ...                1.812
# 16   f1_fuel_1994_12_6_0_7  ...                1.806
# ...

# %%
fuel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   record_id                     29523 non-null  object
#  1   utility_id_ferc1              29523 non-null  int64
#  2   report_year                   29523 non-null  int64
#  3   plant_name_ferc1              29523 non-null  object
#  4   fuel_type_code_pudl           29523 non-null  object
#  5   fuel_unit                     29343 non-null  object
#  6   fuel_qty_burned               29523 non-null  float64
#  7   fuel_mmbtu_per_unit           29523 non-null  float64
#  8   fuel_cost_per_unit_burned     29523 non-null  float64
#  9   fuel_cost_per_unit_delivered  29523 non-null  float64
#  10  fuel_cost_per_mmbtu           29523 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 2.5+ MB

# %%
fuel_data.describe()
# Out:
#        utility_id_ferc1  ...  fuel_cost_per_mmbtu
# count      29523.000000  ...         29523.000000
# mean         118.601836  ...            19.304354
# std           74.178353  ...          2091.540939
# min            1.000000  ...           -41.501000
# 25%           55.000000  ...             1.940000
# 50%          122.000000  ...             4.127000
# 75%          176.000000  ...             7.745000
# max          514.000000  ...        359278.000000
#
# [8 rows x 7 columns]

# %%
fuel_data['report_year'].describe()
# Out:
# count    29523.000000
# mean      2005.806050
# std          7.025483
# min       1994.000000
# 25%       2000.000000
# 50%       2006.000000
# 75%       2012.000000
# max       2018.000000
# Name: report_year, dtype: float64

# %%
fuel_data['plant_name_ferc1'].describe()
# Out:
# count         29523
# unique         2315
# top       big stone
# freq            156
# Name: plant_name_ferc1, dtype: object

# %%
fuel_data['fuel_cost_per_unit_burned'].describe()
# Out:
# count     29523.000000
# mean        208.649031
# std        2854.490090
# min        -276.080000
# 25%           5.207000
# 50%          26.000000
# 75%          47.113000
# max      139358.000000
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
fuel_data['record_id'].describe()
# Out:
# count                       29523
# unique                      29523
# top       f1_fuel_1998_12_132_0_1
# freq                            1
# Name: record_id, dtype: object

# %%
fuel_data['fuel_qty_burned'].describe()
# Out:
# count    2.952300e+04
# mean     2.622119e+06
# std      9.118004e+06
# min      1.000000e+00
# 25%      1.381700e+04
# 50%      2.533220e+05
# 75%      1.424034e+06
# max      5.558942e+08
# Name: fuel_qty_burned, dtype: float64

# %%
fuel_data['fuel_unit'].describe()
# Out:
# count     29343
# unique        9
# top         mcf
# freq      11354
# Name: fuel_unit, dtype: object

# %%
fuel_data['fuel_cost_per_unit_delivered'].describe()
# Out:
# count    2.952300e+04
# mean     9.175704e+02
# std      6.877593e+04
# min     -8.749370e+02
# 25%      3.778500e+00
# 50%      1.737100e+01
# 75%      4.213700e+01
# max      7.964521e+06
# Name: fuel_cost_per_unit_delivered, dtype: float64

# %%
fuel_data['fuel_type_code_pudl'].describe()
# Out:
# count     29523
# unique        6
# top         gas
# freq      11486
# Name: fuel_type_code_pudl, dtype: object

# %%
fuel_data['utility_id_ferc1'].describe()
# Out:
# count    29523.000000
# mean       118.601836
# std         74.178353
# min          1.000000
# 25%         55.000000
# 50%        122.000000
# 75%        176.000000
# max        514.000000
# Name: utility_id_ferc1, dtype: float64

# %%
fuel_data['fuel_cost_per_mmbtu'].describe()
# Out:
# count     29523.000000
# mean         19.304354
# std        2091.540939
# min         -41.501000
# 25%           1.940000
# 50%           4.127000
# 75%           7.745000
# max      359278.000000
# Name: fuel_cost_per_mmbtu, dtype: float64

# %%
fuel_data['report_year'].plot(kind= 'box', vert =False,  figsize = (14,6))  # BoxPlot For Report Year

# %%
fuel_data['fuel_cost_per_unit_burned'].plot(kind='hist',  figsize=(14,6))

# %%
fuel_data['report_year'].plot(kind= 'density', figsize = (14,6))

# %%
fuel_data['fuel_qty_burned'].plot(kind= 'density', figsize = (14,6))

# %%
ax = fuel_data['fuel_qty_burned'].plot(kind= 'density', figsize = (14,6))
ax.axvline(fuel_data['fuel_qty_burned'].mean(), color ='red')
ax.axvline(fuel_data['fuel_qty_burned'].median(), color ='green')

# %%
fuel_data['fuel_cost_per_unit_burned'].plot(kind= 'density', figsize = (14,6))

# %% [markdown]
# # Categorical Analysis and Visualization

# %%
fuel_data['report_year'].value_counts()
# Out:
# 2000    1373
# 2001    1356
# 2005    1269
# 2007    1264
# 2010    1261
# 2006    1243
# 2012    1243
# 2011    1240
# 1994    1235
# 2008    1228
# 2009    1222
# 2003    1211
# 2002    1205
# 1995    1201
# 2013    1199
# 2004    1192
# 2014    1171
# 1998    1107
# 1997    1094
# 2015    1093
# 1996    1088
# 1999    1050
# 2016    1034
# 2017     993
# 2018     951
# Name: report_year, dtype: int64

# %%
fuel_data['fuel_cost_per_mmbtu'].value_counts()
# Out:
# 0.000     100
# 5.763      35
# 1.060      30
# 1.190      27
# 1.110      26
#          ...
# 15.612      1
# 16.466      1
# 23.491      1
# 3.632       1
# 3.165       1
# Name: fuel_cost_per_mmbtu, Length: 12605, dtype: int64

# %%
fuel_data['fuel_cost_per_unit_burned'].value_counts()
# Out:
# 0.000      288
# 3.050       20
# 2.210       18
# 3.380       18
# 3.560       18
#           ...
# 8.643        1
# 4.508        1
# 2.988        1
# 445.300      1
# 44.000       1
# Name: fuel_cost_per_unit_burned, Length: 19416, dtype: int64

# %%
fuel_data['fuel_cost_per_unit_delivered'].value_counts()
# Out:
# 0.000      3428
# 3.480        41
# 3.310        26
# 3.330        25
# 2.600        24
#            ...
# 28.947        1
# 26.910        1
# 26.745        1
# 9.761         1
# 103.228       1
# Name: fuel_cost_per_unit_delivered, Length: 16675, dtype: int64

# %%
fuel_data['report_year'].value_counts()
# Out:
# 2000    1373
# 2001    1356
# 2005    1269
# 2007    1264
# 2010    1261
# 2006    1243
# 2012    1243
# 2011    1240
# 1994    1235
# 2008    1228
# 2009    1222
# 2003    1211
# 2002    1205
# 1995    1201
# 2013    1199
# 2004    1192
# 2014    1171
# 1998    1107
# 1997    1094
# 2015    1093
# 1996    1088
# 1999    1050
# 2016    1034
# 2017     993
# 2018     951
# Name: report_year, dtype: int64

# %%
fuel_data['report_year'].value_counts().plot( figsize =(14,7))

# %%
fuel_data['report_year'].value_counts().plot(kind = 'pie', figsize =(7,7))

# %%
fuel_data['utility_id_ferc1'].value_counts().plot(kind = 'pie', figsize =(7,7))

# %%
fuel_data['plant_name_ferc1'].value_counts().plot(kind = 'pie', figsize =(7,7))

# %%
fuel_data['report_year'].value_counts().plot(kind = 'bar', figsize =(14,6))

# %%
fuel_data.corr()
# Out:
#                               utility_id_ferc1  ...  fuel_cost_per_mmbtu
# utility_id_ferc1                      1.000000  ...             0.006122
# report_year                           0.093323  ...             0.010261
# fuel_qty_burned                      -0.057447  ...            -0.001896
# fuel_mmbtu_per_unit                  -0.066946  ...            -0.005884
# fuel_cost_per_unit_burned            -0.037863  ...            -0.000437
# fuel_cost_per_unit_delivered         -0.016414  ...            -0.000109
# fuel_cost_per_mmbtu                   0.006122  ...             1.000000
#
# [7 rows x 7 columns]
